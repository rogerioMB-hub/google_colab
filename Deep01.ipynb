# %% [markdown]
# <a href="https://colab.research.google.com/github/rogerioMB-hub/google_colab/blob/main/Deep01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nestes notebooks que se sucedem agora, trataremos de sistemas de classificação de regiões mais restritas.
#
# Assim, tendo que um modelo linear simples não consegue classificar bem nossos dados, combiná-los é uma solução desejada.
#
# Esta combinação linear de outros dois perceptrons, tomando o exemplo, permite restringir uma dada região bem melhor que qualquer uma das versões isoladamente. Vejamos o exemplo abaixo:
#
# ![2perceptrons.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Combinando-os e aplicando a função não-linear sigmoide no resultado obtido, tem-se uma curva como mostrada abaixo. A dificuldade está na escolha dos pesos que levam à sigmoide da saída visando o melhor ajuste da referida curva, mas não só, pois também os ajustes das funções sobre x1 e x2 são igualmente importante, como vimos anteriormente.

# %% [markdown]
# ![2perceptrons2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Que pode ser melhor reescrito da seguinte forma:

# %% [markdown]
# ![2perceptrons3.jpg](data:image/jpeg;base64,...)
